# %%
# !pip show langchain
# Out:
# WARNING: Package(s) not found: langchain

# %%
pip uninstall langchain -y
# Out:
# Found existing installation: langchain 1.1.0
# Uninstalling langchain-1.1.0:
#   Successfully uninstalled langchain-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip show langchain
# Out:
# WARNING: Package(s) not found: langchain

# %%
# !pip install langchain==0.2.6
# Out:
# Collecting langchain==0.2.6
#   Using cached langchain-0.2.6-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\acer\desktop\personal_project\conversational_ai_agents\.env\lib\site-packages (from langchain==0.2.6) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\acer\desktop\personal_project\conversational_ai_agents\.env\lib\site-packages (from langchain==0.2.6) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\acer\desktop\personal_project\conversational_ai_agents\.env\lib\site-packages (from langchain==0.2.6) (3.13.2)
# Collecting langchain-core<0.3.0,>=0.2.10 (from langchain==0.2.6)
#   Downloading langchain_core-0.2.43-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain==0.2.6)
#   Using cached langchain_text_splitters-0.2.4-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.2.6)
#   Using cached langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Collecting numpy<2.0.0,>=1.26.0 (from langchain==0.2.6)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + C:\Users\Acer\Desktop\Personal_Project\conversational_AI_Agents\.env\Scripts\python.exe C:\Users\Acer\AppData\Local\Temp\pip-install-vc9os8ed\numpy_90ff7fa5dadd4664a85efa0a0e789185\vendored-meson\meson\meson.py setup C:\Users\Acer\AppData\Local\Temp\pip-install-vc9os8ed\numpy_90ff7fa5dadd4664a85efa0a0e789185 C:\Users\Acer\AppData\Local\Temp\pip-install-vc9os8ed\numpy_90ff7fa5dadd4664a85efa0a0e789185\.mesonpy-7vfpcs5x -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\Acer\AppData\Local\Temp\pip-install-vc9os8ed\numpy_90ff7fa5dadd4664a85efa0a0e789185\.mesonpy-7vfpcs5x\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\Acer\AppData\Local\Temp\pip-install-vc9os8ed\numpy_90ff7fa5dadd4664a85efa0a0e789185
#       Build dir: C:\Users\Acer\AppData\Local\Temp\pip-install-vc9os8ed\numpy_90ff7fa5dadd4664a85efa0a0e789185\.mesonpy-7vfpcs5x
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] The system cannot find the file specified"
#       Running `cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `cc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `gcc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang-cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `pgcc --version` gave "[WinError 2] The system cannot find the file specified"
#
#       A full log can be found at C:\Users\Acer\AppData\Local\Temp\pip-install-vc9os8ed\numpy_90ff7fa5dadd4664a85efa0a0e789185\.mesonpy-7vfpcs5x\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip show langchain-core
# Out:
# WARNING: Package(s) not found: langchain-core

# %%
# !pip show langchain-openai
# Out:
# Name: langchain-openai
# Version: 1.1.0
# Summary: An integration package connecting OpenAI and LangChain
# Home-page: https://docs.langchain.com/oss/python/integrations/providers/openai
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\Acer\Desktop\Personal_Project\conversational_AI_Agents\.env\Lib\site-packages
# Requires: langchain-core, openai, tiktoken
# Required-by:
